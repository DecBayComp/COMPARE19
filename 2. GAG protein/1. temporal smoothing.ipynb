# %% [markdown]
# This notebook processes experimental data of tracked GAG proteins during the formation of capsids

# %% [markdown]
# # Define parameters

# %%
### Parameters

## files
trajectory_file = 'vlp.txt'

## tessellation
# cell size
resolution = .1 # in um
# minimum numbers of locations per cell
min_n  =  1 # discard below (first)
min_nn = 10 # enlarge below (second)
# time window
win   = 180. # in s
shift =  15. # in s

## inference
sigma = .03 # in um
diffusivity_smoothing = 0.
potential_smoothing   = 1.
time_smoothing        = 1e-2

## movie
frame_rate = 4 # segments per second


## automatic parameters

# files
import os.path
rwa_file = os.path.splitext(trajectory_file)[0]+'.rwa'

# label factories
seg_label = lambda n, nn, t: 'hexagon_res_{:.0f}_win_{:.0f}-{:.0f}_min_{:d}-{:d}_reg_{}'.format(round(resolution * 1e3), win, shift, n, nn, 1 if t else 0)
sdv_label = lambda t: 'sigma_{:.0f}_sdv_d_{:.0f}_v_{:.0f}_t_{:.0f}'.format(round(sigma * 1e3), diffusivity_smoothing, potential_smoothing, round(t*1e3))

# tessellate labels
for_density_label = seg_label(1, 0, 0)
for_sdv_label = seg_label(min_n, min_nn, 0)
for_smooth_sdv_label = seg_label(min_n, min_nn, 1)

# %% [markdown]
# # Tessellate and infer

# %%
from tramway.helper import *
import time

# tessellate common options
cell_sizing = dict(ref_distance=resolution, rel_avg_distance=1., min_location_count=0)
cell_adjust = dict(min_n=min_n, knn=min_nn)
time_segmentation = dict(time_window_duration=win, time_window_shift=shift)

if not os.path.exists(rwa_file):
    
    # segmentation for density estimation
    tessellate(trajectory_file, 'hexagon', output_file=rwa_file,
               **cell_sizing, # cell sizing
               **time_segmentation, # time segmentation
               output_label=for_density_label)
    
    # segmentation for dv inference without temporal smoothing
    tessellate(rwa_file, 'hexagon',
               **cell_sizing, # cell sizing
               **cell_adjust, # filter and adjust the smaller cells
               **time_segmentation, # time segmentation
               output_label=for_sdv_label)
    
    # segmentation for dv inference with temporal smoothing
    tessellate(rwa_file, 'hexagon',
               **cell_sizing, # cell sizing
               **cell_adjust, # filter and adjust the smaller cells
               **time_segmentation, enable_time_regularization=True, # time segmentation
               output_label=for_smooth_sdv_label)

# density
infer(rwa_file, 'density', input_label=for_density_label, output_label='density')

# infer common options
spatial_kwargs = dict(sigma=sigma, diffusivity_prior=diffusivity_smoothing, potential_prior=potential_smoothing)
optim_kwargs   = dict(ftol=1e-2)

# dv without temporal smoothing
t0 = time.time()
infer(rwa_file, 'stochastic.dv',
      **spatial_kwargs,
      **optim_kwargs,
      input_label=for_sdv_label, output_label=sdv_label(0))
print('elapsed time: {:d}s'.format(round(time.time()-t0)))

# dv with temporal smoothing
assert 0 < time_smoothing
t0 = time.time()
infer(rwa_file, 'stochastic.dv',
      **spatial_kwargs, time_prior=time_smoothing,
      **optim_kwargs,
      input_label=for_smooth_sdv_label, output_label=sdv_label(time_smoothing))
print('elapsed time: {:d}s'.format(round(time.time()-t0)))
# Out:
# overwrite file 'vlp.rwa': [N/y] y
# elapsed time: 1826s
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(106791) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(104181) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(6822) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(9432) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(4212) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62018) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(59408) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(64628) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(83893) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(81283) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(86503) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(29913) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(32523) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(27303) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(69477) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(66867) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(72087) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(86081) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(88691) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(83471) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(37474) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(34864) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(40084) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(93336) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(90726) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(102609) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(105219) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(99999) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(25157) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(22547) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(27767) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(11118) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(8508) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(35720) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(38330) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(33110) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(22083) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(24693) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(99131) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(96521) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(25530) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(22920) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(28140) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(103) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(2713) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(16470) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(19080) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(87060) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(84450) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(1604) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(4214) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(16061) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(60234) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(57624) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62844) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(56655) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(59265) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(54045) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(1602) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(51435) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(48825) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(42347) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(44957) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(44539) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(41929) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(47149) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(34797) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(32187) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(37407) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(81416) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(84026) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(78806) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(22493) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(25103) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(3288) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(5898) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(678) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(18973) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(65141) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62531) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(66139) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(63529) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(68749) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(2842) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(232) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(5452) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(91301) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(93911) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(105887) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(103277) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(30500) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(75066) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(72456) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(77676) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(14486) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(17096) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(11876) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(103065) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(105675) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(100455) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(81840) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(79230) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62089) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(45259) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(42649) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(47869) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(106406) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(103796) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(25280) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(27890) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(22670) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(48446) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(51056) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(61704) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(64314) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(59094) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(27713) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(60145) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62755) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(57535) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(14225) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(91590) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(94200) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(88980) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(35933) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(33323) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(38543) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(49481) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(52091) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(46871) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(65454) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(68064) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(78829) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(47847) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(50457) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(45237) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:205: RuntimeWarning: time_derivative(105357, V) failed
#   warn('time_derivative({}, V) failed'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(66397) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(63787) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(20310) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(17262) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(19872) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(14652) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(93776) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(96386) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(91166) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(55870) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(19785) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(22395) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(17175) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(77496) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(80106) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(74886) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(34283) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(31673) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(36893) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(86491) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(83881) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(89101) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(61496) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(64106) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(58886) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(60350) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62960) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(57740) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(39319) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(36709) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(69848) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(72458) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(67238) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(70149) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(67539) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(72759) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(51879) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(54489) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(49759) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(52369) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(40940) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(43550) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(80736) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(83346) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(78126) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(4046) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(6656) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(1436) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(60919) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(58309) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(85506) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(82896) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(88116) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(94466) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(91856) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(97076) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(88566) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(85956) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:205: RuntimeWarning: time_derivative(104452, V) failed
#   warn('time_derivative({}, V) failed'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:205: RuntimeWarning: time_derivative(104453, V) failed
#   warn('time_derivative({}, V) failed'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:205: RuntimeWarning: time_derivative(104408, V) failed
#   warn('time_derivative({}, V) failed'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(17327) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(19937) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(14717) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(19252) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(85526) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(88136) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(82916) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(89113) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(91723) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(89380) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(86770) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(91990) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(4125) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(1515) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(6735) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(44723) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(42113) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(47333) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(9266) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(41153) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(43763) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(62319) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(64929) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(59709) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(90746) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(93356) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(97389) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(94779) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(13646) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(16256) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(11036) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(21453) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(80286) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(90227) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(87617) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(92837) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(56484) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(9092) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(6482) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(11702) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(72906) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(70296) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(75516) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(42963) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(40353) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(45573) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(52553) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(55163) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(49943) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(74703) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(77313) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(72093) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(57589) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(54979) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(60199) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(2542) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(40995) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(38385) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(43605) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(90144) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(87534) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(67056) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(69666) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(64446) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(51249) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(53859) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(24300) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(21690) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(26910) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(34099) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(31489) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(63346) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(40017) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(42627) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(34740) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(32130) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(37350) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(8426) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(99420) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(96810) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(102030) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(95271) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(97881) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(92661) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:205: RuntimeWarning: time_derivative(1328, V) failed
#   warn('time_derivative({}, V) failed'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(94333) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(55587) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(52977) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# /home/francois/github/TRamWAy/tramway/inference/stochastic_dv.py:157: RuntimeWarning: gradV(58197) is not defined
#   warn('gradV({}) is not defined'.format(i), RuntimeWarning)
# elapsed time: 2230s

# %% [markdown]
# # Create videos

# %%
from tramway.helper.animation import *
import os

# parameters
density_suffix =         '_n'
suffix = {'diffusivity': '_d',
          'potential':   '_v',
          'force':       '_f'}
verbose = True

# init
basename = os.path.splitext(rwa_file)[0]
movie_files = []
def grab(seg_label, map_label, feature, suffix):
    movie_file = '{}{}.mp4'.format(basename, suffix)
    movie_files.append(movie_file)
    animate_map_2d_helper(rwa_file,
                          movie_file,
                          label=[seg_label, map_label],
                          feature=feature,
                          frame_rate=frame_rate,
                          play=False, verbose=verbose)

# density
grab(for_density_label, 'density', 'density', density_suffix)

for feature in suffix:
    
    # dv without temporal smoothing
    grab(for_sdv_label, sdv_label(0), feature, suffix[feature])
    
    # dv with temporal smoothing
    _suffix = '_t{:.0f}{}'.format(round(time_smoothing*1e3), suffix[feature])
    grab(for_smooth_sdv_label, sdv_label(time_smoothing), feature, _suffix)
    
import matplotlib.pyplot
matplotlib.pyplot.close('all')
    
# movies to be opened with an external reader
print('''
In: {}
Generated files: {}'''.format(os.getcwd(), ', '.join(movie_files)))
# Out:
# overwrite file 'vlp_n.mp4': [N/y] y
# 100%|██████████| 41/41 [00:06<00:00,  6.63it/s]
# overwrite file 'vlp_d.mp4': [N/y] y
# 100%|██████████| 41/41 [00:05<00:00,  7.71it/s]
# overwrite file 'vlp_t10_d.mp4': [N/y] y
# 100%|██████████| 41/41 [00:05<00:00,  7.57it/s]
# overwrite file 'vlp_v.mp4': [N/y] y
# 100%|██████████| 41/41 [00:05<00:00,  7.74it/s]
# overwrite file 'vlp_t10_v.mp4': [N/y] y
# 100%|██████████| 41/41 [00:05<00:00,  7.41it/s]
# overwrite file 'vlp_f.mp4': [N/y] y
# 100%|██████████| 41/41 [00:10<00:00,  4.04it/s]
# overwrite file 'vlp_t10_f.mp4': [N/y] y
# 100%|██████████| 41/41 [00:10<00:00,  3.81it/s]
# In: /home/francois/github/COMPARE19/2. GAG protein
# Generated files: vlp_n.mp4, vlp_d.mp4, vlp_t10_d.mp4, vlp_v.mp4, vlp_t10_v.mp4, vlp_f.mp4, vlp_t10_f.mp4

# %% [markdown]
# ## Watch the videos

# %%
from IPython.display import HTML

width, height = 480, 360

# density
HTML('''
<video width="{}" height="{}" controls>
  <source src="{}" type="video/mp4">
</video>
'''.format(width, height, movie_files[0]))
# Out:
# <video width="480" height="360" controls>
#   <source src="vlp_n.mp4" type="video/mp4">
# </video>

# %%
from IPython.display import HTML

# diffusivity
HTML('''
<div style="white-space: no-wrap">
<video width="{}" height="{}" controls>
  <source src="{}" type="video/mp4">
</video>
<video width="{}" height="{}" controls>
  <source src="{}" type="video/mp4">
</video>
</div>
'''.format(width, height, movie_files[1], width, height, movie_files[4]))
# Out:
# <div style="white-space: no-wrap">
# <video width="480" height="360" controls>
#   <source src="vlp_d.mp4" type="video/mp4">
# </video>
# <video width="480" height="360" controls>
#   <source src="vlp_t10_v.mp4" type="video/mp4">
# </video>
# </div>

# %% [markdown]
# # Access the inferred parameters
#
# We are going to compare the time course of the potential energy at a selected cell.

# %%
# load the file and pick and choose a cell
from tramway.helper import *

analyses = load_rwa(rwa_file)

cell_plot(analyses, label=for_density_label, cell_indices=True, locations=dict(size=2), figsize=(12,9),show=False)
ax = plt.gca()
ax.set_xlim([17.5,18])
ax.set_ylim([15.7,16.2])
plt.show()

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

# extract the potential energy maps
cells = analyses[for_sdv_label].data

maps  = analyses[for_sdv_label][sdv_label(0)].data
V     = maps['potential']
# remember: cells are replicated for each segments and cell indices do not match those above
V
# Out:
#         potential
# 0        3.561999
# 1        3.545205
# 2        3.537729
# 3        3.532843
# 4        3.527160
# 5        3.553937
# 6        3.540959
# 7        3.543565
# 8        3.541476
# 9        3.540149
# 10       3.540139
# 11       3.540959
# 12       3.541554
# 13       3.540180
# 14       3.536494
# 15       3.544594
# 25       3.555619
# 26       3.537277
# 27       3.544796
# 29       3.135512
# 30       2.956771
# 31       3.543915
# 32       2.708227
# 33       2.547456
# 34       3.540859
# 38       3.601078
# 44       3.503912
# 45       3.535625
# 46       3.205318
# 47       3.542685
# ...           ...
# 106065   3.409480
# 106107   3.540959
# 106108   2.546057
# 106109   3.541755
# 106151   3.540959
# 106152   3.520386
# 106196   3.564370
# 106327   3.541125
# 106352   3.540959
# 106370   3.542378
# 106371   3.539337
# 106395   3.540959
# 106414   3.541130
# 106667   3.540946
# 106668   2.900831
# 106675   3.542682
# 106676   3.540770
# 106710   3.540382
# 106711   0.681689
# 106712   3.537479
# 106718   3.543976
# 106719   3.008214
# 106720   3.538585
# 106754   3.540792
# 106755   3.540184
# 106762   3.538625
# 106763   3.356377
# 106764   3.539320
# 106807   3.541517
# 106808   3.544376
#
# [14949 rows x 1 columns]

# %%
seg_V = cells.tessellation.split_frames(V, return_times=True)
# now the maps corresponding to the different time segments have adequate indices
seg_V[0][1]
# Out:
#       potential
# 0      3.561999
# 1      3.545205
# 2      3.537729
# 3      3.532843
# 4      3.527160
# 5      3.553937
# 6      3.540959
# 7      3.543565
# 8      3.541476
# 9      3.540149
# 10     3.540139
# 11     3.540959
# 12     3.541554
# 13     3.540180
# 14     3.536494
# 15     3.544594
# 25     3.555619
# 26     3.537277
# 27     3.544796
# 29     3.135512
# 30     2.956771
# 31     3.543915
# 32     2.708227
# 33     2.547456
# 34     3.540859
# 38     3.601078
# 44     3.503912
# 45     3.535625
# 46     3.205318
# 47     3.542685
# ...         ...
# 1882   3.535203
# 1883   3.541192
# 1886   3.535957
# 1887   3.542869
# 1914   3.393215
# 1915   3.689226
# 1925   3.540959
# 1929   3.546943
# 1958   3.590424
# 2012   3.523598
# 2013   3.302118
# 2055   3.587290
# 2056   1.979967
# 2057   2.970076
# 2058   3.552570
# 2099   3.520026
# 2100   1.737021
# 2101   3.536588
# 2142   3.721009
# 2143   3.466450
# 2144   3.555664
# 2186   3.442450
# 2187   3.540548
# 2188   3.543010
# 2229   3.790959
# 2230   3.464448
# 2231   2.846832
# 2232   3.540908
# 2274   3.540959
# 2275   3.540087
#
# [518 rows x 1 columns]

# %%
# find cells (their indices) with defined potential energy in all segments
ix = [ set(_v.index.tolist()) for _, _v in seg_V ]
ix = ix[0].intersection(*ix[1:])
ix

# %%
cell_index = 959

# complete the value extraction...
seg, t, v  = zip(*[(   _seg,   (_seg[0] + _seg[1]) / 2,   _v.loc[cell_index]   ) for _seg, _v in seg_V ])
t, v  = np.array(t), np.array(v)

smooth_maps = analyses[for_smooth_sdv_label][sdv_label(time_smoothing)].data
smooth_V    = smooth_maps['potential']
smooth_V    = cells.tessellation.split_frames(smooth_V)
smooth_v    = np.array([ _v.loc[cell_index] for _v in smooth_V ])

# ... and plot
def plot(_v, _c):
    plt.plot([seg[0][0], t[0], None, t[-1], seg[-1][-1]], [_v[0], _v[0], None, _v[-1], _v[-1]], _c+':', linewidth=1.5)
    plt.plot(t, _v, _c+'-', linewidth=1.5)
    
plot(v, 'r')
plot(smooth_v, 'g')
plt.show()
